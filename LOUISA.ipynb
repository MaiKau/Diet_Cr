# %%
from selenium import webdriver
from bs4 import BeautifulSoup,NavigableString,Tag
import requests
import pyodbc
import time
# category_list=['https://www.louisacoffee.co/products_list/13','https://www.louisacoffee.co/products_list/14']

res=requests.get('https://www.louisacoffee.co/products_list/13',verify=False)
soup=BeautifulSoup(res.text)

content_title=[] #品名
content_list=[] #內容
content_list_combine=[]

for title in soup.find_all('p',{'class':'mb0'}): # for title in soup2.find_all('h5',{'class':'mb1'}): // for title in soup.find_all('p',{'class':'mb0'}):
    content_title.append(title.text)

for k in soup.find_all('table',{'class':'table detail'}):
    content_list.append(k.text)
    
content_list_combine=list(itertools.chain.from_iterable(zip(content_title,content_list)))
# Out:
# C:\Users\Hank\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
b=[]
num=-1
num_list=len(content_list_combine)/2
for abc in range(0,len(content_list_combine),2):
    b.append(content_list_combine[abc:abc+2])
for cde in content_list_combine:
    num=num+1
    if num > num_list-1:
        break
    else:
        content_list_combine=(b[num][0:2])
        print(content_list_combine)
# Out:
# ['豬肉起司瑪芬堡\n                                                     Pork & Cheese\n                        ', '\n\n成分瑪芬堡、豬肉排、起司片、起司醬 淨重133.3 公克 熱量318.9 大卡 蛋白質16.3 公克 總脂肪含量13.9 公克 飽和脂肪6.8 公克 反式脂肪0.2 公克 碳水化合物32.0 公克 糖4.7 公克 鈉756.3 毫克 \n']
# ['豬肉瑪芬堡加蛋 \n                                                     Pork, Egg & Cheese\n                        ', '\n\n成分瑪芬堡、豬肉排、蛋、起司片、起司醬 淨重186.8 公克 熱量390.6 大卡 蛋白質23.0 公克 總脂肪含量18.6 公克 飽和脂肪8.4 公克 反式脂肪0.2 公克 碳水化合物32.9 公克 糖4.8 公克 鈉831.2 毫克 \n']
# ['雙層豬肉瑪芬堡\n                                                     Double Pork & Cheese\n                        ', '\n\n成分瑪芬堡、豬肉排、起司片、起司醬 淨重183.3 公克 熱量435.4 大卡 蛋白質24.6 公克 總脂肪含量21.5 公克 飽和脂肪10.2 公克 反式脂肪0.2 公克 碳水化合物35.2 公克 糖5.8 公克 鈉978.2 毫克 \n']
# ['雙層豬肉瑪芬堡加蛋\n                                                     Double Pork, Egg & Cheese \n                        ', '\n\n成分瑪芬堡、豬肉排、蛋、起司片、起司醬 淨重236.8 公克 熱量507.1 大卡 蛋白質31.3 公克 總脂肪含量26.2 公克 飽和脂肪11.8 公克 反式脂肪0.2 公克 碳水化合物36.1 公克 糖5.9 公克 鈉1053.1 毫克 \n']
# ...
